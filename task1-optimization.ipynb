# %% [markdown]
# ## Columbia University
# ### ECBM E4040 Neural Networks and Deep Learning. Fall 2021.

# %% [markdown]
# ## Assignment 2 - Task 1: Optimization
#
# In this task, we introduce several improved stochastic gradient descent (SGD) based optimization methods. Plain/naive SGD is a reasonable method to update neural network parameters. However, to make SGD perform well, one would need to find an appropriate learning rate and a good initial value. Otherwise, the network will get stuck if the learning rate is small, or it will diverge if the learning rate is too large. In reality, since we have no prior knowledge about the training data, it is not trivial to find a good learning rate manually. Also, when the network becomes deeper, for each layer one may need to set a different learning rate. Another common problem is the lack of sufficient training data. This can cause the training to get stuck when using the naive SGD method. These are the limitations of the plain SGD, which are motivators for creating and using improved SGD-based methods.
#
# To understand the process of setting a good learning rate, one can rely on adaptive learning rate methods. Here, you are going to experiment with **SGD with momentum**, **SGD with nesterov momentum**, **AdaGrad**, **Adam** and compare them against one another.
# All of these optimizers are adaptive learning rate methods. Here is a useful link to learn more about each method used in this task: http://ruder.io/optimizing-gradient-descent/.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Import modules
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# ## Load Fashion-MNIST
#
# Here we use a small dataset with only 2500 samples to simulate the "lack-of-data" situation.

# %%
# Load the raw Fashion-MNIST data.
train, val = fashion_mnist.load_data()

X_train_raw, y_train = train
X_val_raw, y_val = val

X_train = X_train_raw.reshape((X_train_raw.shape[0], X_train_raw.shape[1]**2))
X_val = X_val_raw.reshape((X_val_raw.shape[0], X_val_raw.shape[1]**2))

#Consider a subset of 2500 samples of the 60000 total images (indexed 10000 ~ 12500)
X_val = X_train[10000:10500,:]
y_val = y_train[10000:10500]
X_train = X_train[10500:12500,:]
y_train = y_train[10500:12500]

mean_image = np.mean(X_train, axis=0).astype(np.float32)
X_train = X_train.astype(np.float32) - mean_image
X_val = X_val.astype(np.float32) - mean_image

# We have vectorized the data for you. That is, we flatten the 32×32×3 images into 1×3072 Numpy arrays.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# Training data shape:  (2000, 784)
# Training labels shape:  (2000,)
# Validation data shape:  (500, 784)
# Validation labels shape:  (500,)

# %% [markdown]
# ## Part 1: Implement Several Optimizers
#
# Instructors provide code snippets for testing student code implementations.
#
# The best anticipated achievable accuracies are around 0.3-0.4.

# %%
from utils.neuralnets.mlp import MLP

# %% [markdown]
# ### Original SGD with learning rate decay (for comparison purposes only)

# %%
from utils.optimizers import SGDOptim

model = MLP(input_dim=X_train.shape[1], hidden_dims=[100, 100], num_classes=10, weight_scale=1e-3, l2_reg=0.0)
optimizer = SGDOptim()
hist_sgd = optimizer.train(model, X_train, y_train, X_val, y_val, 
                           num_epoch=30, batch_size=200, learning_rate=1e-2, learning_decay=0.95, 
                           verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.114, new learning rate = 0.0095
# epoch 2: valid acc = 0.192, new learning rate = 0.009025
# epoch 3: valid acc = 0.192, new learning rate = 0.00857375
# epoch 4: valid acc = 0.198, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.208, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.202, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.204, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.194, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.198, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.2, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.204, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.208, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.21, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.206, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.202, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.202, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.206, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.206, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.206, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.206, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.206, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.208, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.208, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.206, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.206, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.206, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.208, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.208, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.208, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.208, new learning rate = 0.0021463876394293723

# %% [markdown]
# ### SGD + Momentum
#
# <span style="color:red">__TODO:__</span> Implement SGD + Momentum by editing **SGDmomentumOptim** in __./utils/optimizers.py__

# %%
# Verification code for your implemention
# Please don't change anything.

from utils.optimizers import SGDmomentumOptim

model = MLP(input_dim=X_train.shape[1], hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3, momentum=0.8)
optimizer = SGDmomentumOptim(model, momentum=0.8)
hist_sgd_momentum = optimizer.train(model, X_train, y_train, X_val, y_val, 
                                         num_epoch=30, batch_size=200, learning_rate=1e-2, 
                                         learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.152, new learning rate = 0.0095
# epoch 2: valid acc = 0.198, new learning rate = 0.009025
# epoch 3: valid acc = 0.206, new learning rate = 0.00857375
# epoch 4: valid acc = 0.224, new learning rate = 0.0081450625
# epoch 5: valid acc = 0.216, new learning rate = 0.007737809374999999
# epoch 6: valid acc = 0.216, new learning rate = 0.007350918906249998
# epoch 7: valid acc = 0.218, new learning rate = 0.006983372960937498
# epoch 8: valid acc = 0.348, new learning rate = 0.006634204312890623
# epoch 9: valid acc = 0.412, new learning rate = 0.006302494097246091
# epoch 10: valid acc = 0.422, new learning rate = 0.005987369392383786
# epoch 11: valid acc = 0.426, new learning rate = 0.005688000922764597
# epoch 12: valid acc = 0.41, new learning rate = 0.005403600876626367
# epoch 13: valid acc = 0.432, new learning rate = 0.005133420832795048
# epoch 14: valid acc = 0.444, new learning rate = 0.0048767497911552955
# epoch 15: valid acc = 0.526, new learning rate = 0.00463291230159753
# epoch 16: valid acc = 0.556, new learning rate = 0.0044012666865176535
# epoch 17: valid acc = 0.554, new learning rate = 0.004181203352191771
# epoch 18: valid acc = 0.56, new learning rate = 0.003972143184582182
# epoch 19: valid acc = 0.6, new learning rate = 0.0037735360253530726
# epoch 20: valid acc = 0.59, new learning rate = 0.0035848592240854188
# epoch 21: valid acc = 0.602, new learning rate = 0.0034056162628811476
# epoch 22: valid acc = 0.606, new learning rate = 0.0032353354497370902
# epoch 23: valid acc = 0.594, new learning rate = 0.0030735686772502355
# epoch 24: valid acc = 0.612, new learning rate = 0.0029198902433877237
# epoch 25: valid acc = 0.588, new learning rate = 0.0027738957312183374
# epoch 26: valid acc = 0.668, new learning rate = 0.0026352009446574203
# epoch 27: valid acc = 0.69, new learning rate = 0.002503440897424549
# epoch 28: valid acc = 0.692, new learning rate = 0.0023782688525533216
# epoch 29: valid acc = 0.688, new learning rate = 0.0022593554099256553
# epoch 30: valid acc = 0.692, new learning rate = 0.0021463876394293723

# %% [markdown]
# ### AdaGrad
#
# <span style="color:red">__TODO:__</span> Implement Adam by editing **AdaGradOptim** in ./utils/optimizers.py

# %%
# Verification code for your implemention
# Please don't change anything.

from utils.optimizers import AdaGradOptim

model = MLP(input_dim=X_train.shape[1], hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = AdaGradOptim(model)
hist_adagrad = optimizer.train(model, X_train, y_train, X_val, y_val, 
                               num_epoch=30, batch_size=200, learning_rate=1e-3, 
                               learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.206, new learning rate = 0.00095
# epoch 2: valid acc = 0.216, new learning rate = 0.0009025
# epoch 3: valid acc = 0.288, new learning rate = 0.000857375
# epoch 4: valid acc = 0.36, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.366, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.376, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.394, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.406, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.406, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.408, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.42, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.486, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.486, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.488, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.568, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.532, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.534, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.544, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.552, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.564, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.576, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.582, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.588, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.59, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.592, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.59, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.596, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.602, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.606, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.61, new learning rate = 0.00021463876394293716

# %% [markdown]
# ### Adam
#
# <span style="color:red">__TODO:__</span> Implement Adam by editing **AdamOptim** in ./utils/optimizers.py

# %%
# Verification code for your implemention
# Please don't change anything.

from utils.optimizers import AdamOptim

model = MLP(input_dim=X_train.shape[1], hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = AdamOptim(model)
hist_adam = optimizer.train(model, X_train, y_train, X_val, y_val, 
                            num_epoch=30, batch_size=200, learning_rate=1e-3, 
                            learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.208, new learning rate = 0.00095
# epoch 2: valid acc = 0.302, new learning rate = 0.0009025
# epoch 3: valid acc = 0.342, new learning rate = 0.000857375
# epoch 4: valid acc = 0.432, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.502, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.59, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.62, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.7, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.736, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.766, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.75, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.77, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.804, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.814, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.776, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.764, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.836, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.804, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.832, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.848, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.808, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.824, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.836, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.83, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.84, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.836, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.852, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.824, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.838, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.832, new learning rate = 0.00021463876394293716

# %% [markdown]
# ### Nadam
#
# <span style="color:red">__TODO:__</span> Implement Nadam by editing **NadamOptim** in __./utils/optimizers.py__.

# %%
# Verification code for your implemention
# Please don't change anything.

from utils.optimizers import NadamOptim

model = MLP(input_dim=X_train.shape[1], hidden_dims=[100, 100], num_classes=10, l2_reg=0.0, weight_scale=1e-3)
optimizer = NadamOptim(model, beta1=0.9, beta2=0.999, eps=1e-8)
hist_sgd_nadam = optimizer.train(model, X_train, y_train, X_val, y_val, 
                                         num_epoch=30, batch_size=200, learning_rate=1e-3, 
                                         learning_decay=0.95, verbose=False, record_interval=1)
# Out:
# number of batches for training: 10
# epoch 1: valid acc = 0.164, new learning rate = 0.00095
# epoch 2: valid acc = 0.392, new learning rate = 0.0009025
# epoch 3: valid acc = 0.392, new learning rate = 0.000857375
# epoch 4: valid acc = 0.572, new learning rate = 0.0008145062499999999
# epoch 5: valid acc = 0.632, new learning rate = 0.0007737809374999998
# epoch 6: valid acc = 0.706, new learning rate = 0.0007350918906249997
# epoch 7: valid acc = 0.61, new learning rate = 0.0006983372960937497
# epoch 8: valid acc = 0.56, new learning rate = 0.0006634204312890621
# epoch 9: valid acc = 0.694, new learning rate = 0.000630249409724609
# epoch 10: valid acc = 0.756, new learning rate = 0.0005987369392383785
# epoch 11: valid acc = 0.75, new learning rate = 0.0005688000922764595
# epoch 12: valid acc = 0.772, new learning rate = 0.0005403600876626365
# epoch 13: valid acc = 0.754, new learning rate = 0.0005133420832795047
# epoch 14: valid acc = 0.768, new learning rate = 0.00048767497911552944
# epoch 15: valid acc = 0.816, new learning rate = 0.00046329123015975297
# epoch 16: valid acc = 0.824, new learning rate = 0.0004401266686517653
# epoch 17: valid acc = 0.826, new learning rate = 0.00041812033521917703
# epoch 18: valid acc = 0.822, new learning rate = 0.00039721431845821814
# epoch 19: valid acc = 0.812, new learning rate = 0.0003773536025353072
# epoch 20: valid acc = 0.81, new learning rate = 0.0003584859224085418
# epoch 21: valid acc = 0.776, new learning rate = 0.0003405616262881147
# epoch 22: valid acc = 0.8, new learning rate = 0.00032353354497370894
# epoch 23: valid acc = 0.816, new learning rate = 0.00030735686772502346
# epoch 24: valid acc = 0.83, new learning rate = 0.00029198902433877225
# epoch 25: valid acc = 0.752, new learning rate = 0.00027738957312183364
# epoch 26: valid acc = 0.76, new learning rate = 0.0002635200944657419
# epoch 27: valid acc = 0.796, new learning rate = 0.0002503440897424548
# epoch 28: valid acc = 0.832, new learning rate = 0.00023782688525533205
# epoch 29: valid acc = 0.828, new learning rate = 0.00022593554099256544
# epoch 30: valid acc = 0.824, new learning rate = 0.00021463876394293716

# %% [markdown]
# ## Part 2: Comparison
#
# <span style="color:red">__TODO:__</span> Run the following cells, which plot the loss, training accuracy, and validation accuracy curves of different optimizers.

# %%
loss_hist_sgd, train_acc_hist_sgd, val_acc_hist_sgd = hist_sgd
loss_hist_momentum, train_acc_hist_momentum, val_acc_hist_momentum = hist_sgd_momentum
loss_hist_nesterov, train_acc_hist_nesterov, val_acc_hist_nesterov = hist_sgd_nadam
loss_hist_adagrad, train_acc_hist_adagrad, val_acc_hist_adagrad = hist_adagrad
loss_hist_adam, train_acc_hist_adam, val_acc_hist_adam = hist_adam

# %%
# Plot the training error curves for implemented optimizers
plt.plot(loss_hist_sgd, label="sgd")
plt.plot(loss_hist_momentum, label="momentum")
plt.plot(loss_hist_nesterov, label="nadam")
plt.plot(loss_hist_adagrad, label="adagrad")
plt.plot(loss_hist_adam, label="adam")
plt.legend()
plt.show()

# %%
# Plot the training accuracy curves for implemented optimizers
plt.plot(train_acc_hist_sgd, label="sgd")
plt.plot(train_acc_hist_momentum, label="momentum")
plt.plot(train_acc_hist_nesterov, label="nadam")
plt.plot(train_acc_hist_adagrad, label="adagrad")
plt.plot(train_acc_hist_adam, label="adam")
plt.legend()
plt.show()

# %%
# Plot the validation accuracy curves for implemented optimizers
plt.plot(val_acc_hist_sgd, label="sgd")
plt.plot(val_acc_hist_momentum, label="momentum")
plt.plot(val_acc_hist_nesterov, label="nadam")
plt.plot(val_acc_hist_adagrad, label="adagrad")
plt.plot(val_acc_hist_adam, label="adam")
plt.legend()
plt.show()

# %% [markdown]
# <span style="color:red">__TODO:__</span> Describe your results, and discuss your understandings of these optimizers, such as their advantages/disadvantages and when to use them.

# %% [markdown]
# Answer: The results show that all of these updated optimizers do better faster than simple SGD. SGD will converge on a minimum, it just might take a long time. So if time/resources are not an issue, and you have a relatively small learning task, this is an ok optimizer to go with.
#
# SGD descent with momentum starts out decreasing the error at about the same rate as simple SGD, then it starts decreasing faster, which makes sense, as the momentum builds.
#
# Adagrad starts out doing a bit better than SGD with momentum, as it is performing unique updates for each of the parameters. However, over time Adagrad's learning slows because its learning rate tends towards 0 because of the exponentially increasing denominator with the sum of squared gradients. Eventually it is effectively unable to learn anymore. Adagrad is good to use with sparse data, since it performs large updates for rarely used params. For example, it can be helpful when training in language tasks, because there are often words that occur very infrequently but still matter to the model.
#
# Adam does much better than the previous optimizers, decreasing the error quickly at first, and then slowing down by the end. We can see it is more likely to stick in the flat minimima of the loss functions and stay there. Instead of continually exponentially updating the denominator with the sum of squared previous gradients, Adam keeps a rolling average of the past squared gradients that decays over time so that its learning rate doesn't vanish like Adagrad's.
#
# Nadam does better than most of the previous optimizers, but given the plots, it is roughly equivalent to Adam. With Nadam, instead of calculating the gradients based on the params at t-1, we preemtively apply the momentum to the params to look at approximately what the params will be (without the gradient update), and then use these approximate params to calculate the gradient used in the final param update.
#
# If the learning task is large, your network is very deep, and you want to optimize for efficiency, Adam or Nadam are probably the best choices.
